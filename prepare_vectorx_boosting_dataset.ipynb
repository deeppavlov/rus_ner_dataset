# %%
import sys
import csv
from datetime import datetime
import pytz, dateutil
from natasha import OrganisationExtractor

DATA_ALL_FILE = '/data/NER/VectorX/dataset.csv'
BOOST_TOLOKA_TRAIN_FILE = '/data/NER/VectorX/toloka_{}_boost.tsv'

# %%
csv.field_size_limit(sys.maxsize)

data = []
with open(DATA_ALL_FILE) as fr:
    cr = csv.reader(fr)
    header = next(cr)
    for row in cr:
        data.append(row)

# %%
# %%time

target_date = datetime(2017, 8, 1).replace(tzinfo=pytz.UTC).date()
# target_date = datetime(2017, 8, 31).replace(tzinfo=pytz.UTC).date()
toloka_file = BOOST_TOLOKA_TRAIN_FILE.format(target_date)

print(f'Writing to file {toloka_file}')

c = 0
with open(toloka_file, 'w') as fw:
    cw = csv.writer(fw, delimiter='\t')
    cw.writerow(['INPUT:guid', 'INPUT:orig', 'INPUT:input'])
    for guid, description, description_tokenized, token_count, pub_date, objects, sdwr in data:        
        row_date = dateutil.parser.parse(pub_date).date()
        if 40 < int(token_count) < 1750 and row_date == target_date and float(sdwr) < 0.15:
            c += 1
            cw.writerow([guid, description, description_tokenized])
        if int(guid) % 5 == 0:
            break
print(f'wrote {c} articles')
# Out:
# Writing to file /data/NER/VectorX/toloka_2017-08-01_boost.tsv
# wrote 0 articles
# CPU times: user 2.18 ms, sys: 62 µs, total: 2.25 ms
# Wall time: 1.83 ms

# %%
oe = OrganisationExtractor()

# %%
matches = oe(description)
matches
# Out:
# Matches('В СБУ не понимают, как российские журналисты узнают информацию, доступную только представителям украинской спецслужбы. Об этом на брифинге в Киеве заявил глава СБУ Василий Грицак, передает корреспондент "ПолитНавигатора".\n\nПодпишитесь на новости "ПолитНавигатор" в\xa0Telegram,\xa0Facebook,\xa0\xa0Одноклассниках\xa0или\xa0Вконтакте\n\nПо его словам, российские СМИ узнали о проведении широкомасштабной спецоперации СБУ по задержанию "диверсантов" в то время, как никто из украинских коллег даже не подозревал о ней.\n\n\n\nТак, СБУ отчиталась о раскрытии "механизма ФСБ", благодаря которому в тёмную использовались бывшие боевики т.н. "АТО". Согласно схеме, "российские силовики" вышли на трех бывших "атошников" и предложили им работу на стройке в Москве за хороший заработок. Им были выданы мобильные телефоны, сумки с инструментами и одежда. В дальнейшем, по словам Грицака, это должно было быть использовано как доказательство подготовки Украиной терактов в Москве.\n\nПо приезду в российскую столицу агент якобы провез украинцев по стратегическим местам - метро и вокзалам Москвы. Все это снималось на видео, чтобы потом обвинить боевиков в подготовке терактов и склонить их на свою сторону. Однако, по словам Грицака, украинские боевики прознали о схеме и смогли сбежать из Москвы благодаря местным "товарищам".\n\nКроме того, Грицак отчитался о задержании трех диверсионных групп, которые на Украине якобы планировали серию терактов и убийств видных политиков.\n\n"Мы не планировали проводить брифинг и собирать прессу, но были вынуждены это сделать из-за того, что мы провели спецоперацию, о которой не знал, в принципе, никто в украинском обществе, не информировали прессу, не делали никакого обнародования, но были очень удивлены, когда о результатах нашей работы.очень быстро узнали в России. На Елену Гитлянскую, руководителя нашего пресс-центра, вышло российское СМИ и поинтересовалось об одном человеке, которого мы действительно задержали. О задержании этого человека было известно только сотрудникам СБУ, понятым, очень узкому кругу",- заявил Грицак.\n\nТакже на брифинге он обвинил российские спецслужбы в активизации подрывной деятельности на Украине.\n\n"У нас есть оперативная информация относительно дальнейшей эскалации разведывательно-террористической деятельности российских спецслужб на территории нашего государства. Российская Федерация продолжает направлять на украинскую землю группы для осуществления террористических актов на нашей территории", - утверждает глава СБУ.\n\nПравозащитник Максим Сытенков в своем блоге на сайте "Корреспондент" назвал брифинг главы СБУ "развешиванием лапши на уши", а ответы Грицака на уточняющие вопросы журналистов после брифинга - болтовней.\n\n"Как-то серо выглядел Грицак Василий на брифинге, особенно когда дошло до вопросов журналистов. На все предметные вопросы по своим фантазиям отвечал, что "не знаю, спросите у ФСБ", или что "это тайна следствия". Чего тогда собирали журналистов? Хотели ответить на задержание в Крыму? Очень смешно и неубедительно получилось… Другое дело призывы. Это у нашего историка получается замечательно. Призывать с высоты своей должности к ущемлению прав на свободу слова, прав на мирные собрания, бросать невинных в тюрьмы, похищать и удерживать людей, давить на суды, при этом используя все специальные возможности, которые есть у спецслужбы - это получается. Превратил Василий всех офицеров в личную охрану спокойствия Порошенко", - отметил Сытенков.\n\nЕще более жестко высказался в адрес главы СБУ известный украинский юрист Андрей Портнов.\n\n"Только увидел вчерашнюю пресс-конференцию главы СБУ Грицака о воинах АТО, уехавших со специальными сумками на заработки в Россию.\xa0Люди добрые, ну какой же вы все таки для такой должности примитивный и тупой", - написал Портнов в своем блоге.\n\n\nЕсли вы нашли ошибку, пожалуйста, выделите фрагмент текста и нажмите Ctrl+Enter.\n\n\n Метки: Василий Грицак, СБУ',
#         [Match([MorphToken('ФСБ',
#                            [543, 546),
#                            'RU',
#                            [Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,gent,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,ablt,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,inan,nomn,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,datv,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,accs,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,inan,loct,sing))])],
#                [543, 546)),
#          Match([MorphToken('диверсионных',
#                            [1341, 1353),
#                            'RU',
#                            [Form('диверсионный', Grams(ADJF,gent,plur)),
#                             Form('диверсионный', Grams(ADJF,accs,anim,plur)),
#                             Form('диверсионный', Grams(ADJF,loct,plur))]),
#                 MorphToken('групп',
#                            [1354, 1359),
#                            'RU',
#                            [Form('группа', Grams(NOUN,femn,gent,inan,plur))])],
#                [1341, 1359)),
#          Match([MorphToken('украинском',
#                            [1608, 1618),
#                            'RU',
#                            [Form('украинский',
#                                  Grams(ADJF,Geox,loct,masc,sing)),
#                             Form('украинский',
#                                  Grams(ADJF,Geox,loct,neut,sing))]),
#                 MorphToken('обществе',
#                            [1619, 1627),
#                            'RU',
#                            [Form('общество',
#                                  Grams(NOUN,inan,loct,neut,sing))])],
#                [1608, 1627)),
#          Match([MorphToken('ФСБ',
#                            [2847, 2850),
#                            'RU',
#                            [Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,gent,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,ablt,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,inan,nomn,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,datv,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,accs,femn,inan,sing)),
#                             Form('фсб',
#                                  Grams(Abbr,Fixd,NOUN,Orgn,Sgtm,femn,inan,loct,sing))])],
#                [2847, 2850))])

# %%
for match in matches:
    print(match.span, match.fact)
# Out:
# [543, 546) Organisation(name='ФСБ')
# [1341, 1359) Organisation(name='диверсионных групп')
# [1608, 1627) Organisation(name='украинском обществе')
# [2847, 2850) Organisation(name='ФСБ')
